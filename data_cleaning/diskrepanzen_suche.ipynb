# %% [markdown]
# Verwende vorhandenes Wissen über die Daten (Metadaten): welchen Typ sollte ein Attribut haben? Welche Werte können wir erwarten (z.B. Alter >=0)? Gibt es Zusammenhänge zwischen den Attributen (z.B. Alter und Geburtsdatum)?
# Deskriptive Zusammenfassungen der Daten (sog. data summaries) zeigen Datentypen und Wertebereiche von Attributen und fassen statistische Eigenschaften der Daten zusammen, z.B. Mittelwert, Ausreißer.
# Regeln prüfen: Eindeutigkeit (Identifier); Definition für fehlende Werte
# Achte auf inkonsistente Repräsentationen: z.B. "2004/12/25" vs. "25/12/2004"

# %%
import pandas as pd
import os

# %%
# ganzer Datensatz
data = pd.read_csv("../data/GeneralDatensatz18-21ohneGeo-mitLockdown.csv", sep=';', encoding='ISO-8859-1')
#print(type(data))
print(data.shape) # da ist was schiefgelaufen beim zusammenführen?
data.head(3)
# Out:
# (50118, 19)
#    LAND  BEZ  LOR_ab_2021  UJAHR  UMONAT  USTUNDE  UWOCHENTAG  UKATEGORIE  \
# 0    11    3    3701658.0   2021      11       18           2           3
# 1    11    7    7501134.0   2021      12       19           7           3
# 2    11    4    4100101.0   2021      12       17           4           3
#
#    UART  UTYP1  ULICHTVERH  IstRad  IstPKW  IstFuss  IstKrad  IstGkfz  \
# 0     0      3           2       0       1        0        1        0
# 1     6      2           2       0       1        1        0        0
# 2     5      2           2       0       1        0        0        0
#
#    IstSonstige  USTRZUSTAND  LOCKDOWN
# 0            0            1         0
# 1            0            1         1
# 2            0            0         1

# %%
 data.columns
# Out:
# Index(['LAND', 'BEZ', 'LOR_ab_2021', 'UJAHR', 'UMONAT', 'USTUNDE',
#        'UWOCHENTAG', 'UKATEGORIE', 'UART', 'UTYP1', 'ULICHTVERH', 'IstRad',
#        'IstPKW', 'IstFuss', 'IstKrad', 'IstGkfz', 'IstSonstige', 'USTRZUSTAND',
#        'LOCKDOWN'],
#       dtype='object')

# %%
data['LOCKDOWN'].dtype
# Out:
# dtype('int64')

# %%
# 2018

csv_directory = '../data'
csv_file = 'AfSBBB_BE_LOR_Strasse_Strassenverkehrsunfaelle_2018_Datensatz.csv'
csv_path = os.path.join(csv_directory, csv_file)
data2018 = pd.read_csv(csv_path, sep=';', encoding='ISO-8859-1')
data2019 = pd.read_csv("../data/AfSBBB_BE_LOR_Strasse_Strassenverkehrsunfaelle_2019_Datensatz.csv", sep=';', encoding='ISO-8859-1')
data2020 = pd.read_csv("../data/AfSBBB_BE_LOR_Strasse_Strassenverkehrsunfaelle_2020_Datensatz.csv", sep=';', encoding='ISO-8859-1')
data2021 = pd.read_csv("../data/AfSBBB_BE_LOR_Strasse_Strassenverkehrsunfaelle_2021_Datensatz.csv", sep=';', encoding='ISO-8859-1')

# %%
print(data2018.shape)
print(data2019.shape)
print(data2020.shape)
print(data2021.shape)

data2019.sample(10)
# Out:
# (13652, 25)
# (13390, 24)
# (11810, 24)
# (11267, 23)
#        OBJECTID  LAND  BEZ       LOR               STRASSE  UJAHR  UMONAT  \
# 7317     196620    11   12  12103220        Humboldtstraße   2019       7
# 1697      51693    11    7   7050502   Fritz-Werner-Straße   2019       9
# 5042     194345    11    8   8010301            Reuterkiez   2019       4
# 3072     192375    11    1   1011302  Oranienburger Straße   2019       2
# 5796     195099    11    5   5020626            Adamstraße   2019       5
# 7929     197232    11   12  12103220        Humboldtstraße   2019       7
# 10258    199561    11    2   2020203          Viktoriapark   2019       9
# 9955     199258    11    4   4041137     Flinsberger Platz   2019       9
# 8133     197436    11    5   5010101       Hakenfelde Nord   2019       7
# 5268     194571    11    3   3061332        Helmholtzplatz   2019       5
#
#        USTUNDE  UWOCHENTAG  UKATEGORIE  ...  IstPKW  IstFuss  IstKrad  \
# ...

# %%
# check if ID unique? YES; ALL UNIQUE
# df['spec_col'].is_unique
print(data2018["OBJECTID"].is_unique)
print(data2019["OBJECTID"].is_unique)
print(data2020["OBJECTID"].is_unique)
data2021["OBJECTID"].is_unique
# Out:
# True
# True
# True
# True

# %%
# describe

# beim Jahr und beim Land muss std = 0 sein
data2018.describe()
# Out:
#             OBJECTID     LAND           BEZ           LOR   LOR_ab_2021  \
# count   13652.000000  13652.0  13652.000000  1.364900e+04  1.364900e+04
# mean   190759.521975     11.0      5.425505  5.470655e+06  5.717133e+06
# std     30321.862980      0.0      3.495083  3.514591e+06  3.498361e+06
# min    112695.000000     11.0      1.000000  1.011101e+06  1.100101e+06
# 25%    198395.750000     11.0      2.000000  2.050602e+06  2.500728e+06
# 50%    201808.500000     11.0      5.000000  5.010313e+06  5.100315e+06
# 75%    205221.250000     11.0      8.000000  8.020622e+06  8.200726e+06
# max    208853.000000     11.0     12.000000  1.230431e+07  1.260124e+07
#
#          UJAHR        UMONAT       USTUNDE    UWOCHENTAG    UKATEGORIE  \
# count  13652.0  13652.000000  13652.000000  13652.000000  13652.000000
# mean    2018.0      6.727952     13.473264      4.057427      2.834603
# std        0.0      3.175704      4.773588      1.779118      0.379550
# ...

# %%
data2019.describe()
# Out:
#             OBJECTID     LAND           BEZ           LOR    UJAHR  \
# count   13390.000000  13390.0  13390.000000  1.339000e+04  13390.0
# mean   176308.038462     11.0      5.418820  5.458240e+06   2019.0
# std     50979.499687      0.0      3.480506  3.499219e+06      0.0
# min     49090.000000     11.0      1.000000  1.011101e+06   2019.0
# 25%    192650.250000     11.0      2.000000  2.050602e+06   2019.0
# 50%    195997.500000     11.0      5.000000  5.010311e+06   2019.0
# 75%    199344.750000     11.0      8.000000  8.020620e+06   2019.0
# max    202779.000000     11.0     12.000000  1.230431e+07   2019.0
#
#              UMONAT       USTUNDE    UWOCHENTAG    UKATEGORIE          UART  \
# count  13390.000000  13390.000000  13390.000000  13390.000000  13390.000000
# mean       6.737043     13.444137      4.105900      2.846901      3.520762
# std        3.228971      4.787982      1.804548      0.367081      2.159758
# ...

# %%
data2020.describe()
# Out:
#             OBJECTID     LAND           BEZ           LOR   LOR_ab_2021  \
# count   11810.000000  11810.0  11810.000000  1.180900e+04  1.180900e+04
# mean   122320.450889     11.0      5.575275  5.620350e+06  5.865560e+06
# std     46594.603526      0.0      3.501419  3.522024e+06  3.499178e+06
# min      3187.000000     11.0      1.000000  1.011101e+06  1.100101e+06
# 25%    137079.250000     11.0      2.000000  2.050802e+06  2.500834e+06
# 50%    140031.500000     11.0      5.000000  5.020524e+06  5.200528e+06
# 75%    142983.750000     11.0      8.000000  8.041035e+06  8.401241e+06
# max    146070.000000     11.0     12.000000  1.230431e+07  1.260124e+07
#
#          UJAHR        UMONAT       USTUNDE    UWOCHENTAG    UKATEGORIE  \
# count  11810.0  11810.000000  11810.000000  11810.000000  11810.000000
# mean    2020.0      6.776715     13.523793      4.061135      2.844877
# std        0.0      3.191813      4.684416      1.802461      0.372414
# ...

# %%
data2021.describe()
# Out:
#             OBJECTID     LAND           BEZ   LOR_ab_2021    UJAHR  \
# count   11267.000000  11267.0  11267.000000  1.126600e+04  11267.0
# mean   200048.203870     11.0      5.541227  5.823506e+06   2021.0
# std     34841.735786      0.0      3.478722  3.477900e+06      0.0
# min    109753.000000     11.0      1.000000  1.100101e+06   2021.0
# 25%    210441.500000     11.0      2.000000  2.500835e+06   2021.0
# 50%    213258.000000     11.0      5.000000  5.200420e+06   2021.0
# 75%    216074.500000     11.0      8.000000  8.200832e+06   2021.0
# max    219249.000000     11.0     12.000000  1.260124e+07   2021.0
#
#              UMONAT       USTUNDE    UWOCHENTAG    UKATEGORIE          UART  \
# count  11267.000000  11267.000000  11267.000000  11267.000000  11267.000000
# mean       7.149996     13.605751      4.069761      2.847697      3.515488
# std        3.047300      4.724270      1.808249      0.366908      2.188767
# ...

# %%
data.describe()
# Out:
#           LAND           BEZ   LOR_ab_2021         UJAHR        UMONAT  \
# count  50118.0  50118.000000  5.011300e+04  50118.000000  50118.000000
# mean      11.0      5.484936  5.706762e+06   2019.412866      6.836665
# std        0.0      3.489571  3.497724e+06      1.112136      3.169988
# min       11.0      1.000000  1.011101e+06   2018.000000      1.000000
# 25%       11.0      2.000000  2.500728e+06   2018.000000      4.000000
# 50%       11.0      5.000000  5.100209e+06   2019.000000      7.000000
# 75%       11.0      8.000000  8.200725e+06   2020.000000      9.000000
# max       11.0     12.000000  1.260124e+07   2021.000000     12.000000
#
#             USTUNDE    UWOCHENTAG    UKATEGORIE          UART         UTYP1  \
# count  50118.000000  50118.000000  50118.000000  50118.000000  50118.000000
# mean      13.507283      4.074025      2.843250      3.530767      3.882856
# std        4.745734      1.798072      0.371763      2.172730      1.915349
# ...

# %%
described_data = data.describe()
corona_einfluesse = described_data["UJAHR"]
# corona_einfluesse.to_csv("corona_einfluesse_sichtbar?")
corona_einfluesse
# Out:
# count    50118.000000
# mean      2019.412866
# std          1.112136
# min       2018.000000
# 25%       2018.000000
# 50%       2019.000000
# 75%       2020.000000
# max       2021.000000
# Name: UJAHR, dtype: float64

# %%
# Datentypen überprüfen
data.dtypes

# geodaten sind Objects
# Out:
# LAND             int64
# BEZ              int64
# LOR_ab_2021    float64
# UJAHR            int64
# UMONAT           int64
# USTUNDE          int64
# UWOCHENTAG       int64
# UKATEGORIE       int64
# UART             int64
# UTYP1            int64
# ULICHTVERH       int64
# IstRad           int64
# IstPKW           int64
# IstFuss          int64
# IstKrad          int64
# IstGkfz          int64
# IstSonstige      int64
# USTRZUSTAND      int64
# LOCKDOWN         int64
# dtype: object

# %%
# Anzahl eindeutiger Werte pro Spalte

# bei LOR_ab_2021 sind es zu viele, es gibt eigentlich nicht so viele:
# "Die Systematik der LOR besteht nach der Modifikation aus

    #Planungsräumen (PLR) als unterste Ebene, 542 Räume,
    #Bezirksregionen (BZR) als mittlere Ebene, 143 Räume,
    #Prognoseräumen (PGR) als obere Ebene, 58 Räume."

for col in data.columns:
    print("Spaltenname: ", col)
    print("Anzahl unterschiedlicher Werte: ", data[col].nunique())
# Out:
# Spaltenname:  LAND
# Anzahl unterschiedlicher Werte:  1
# Spaltenname:  BEZ
# Anzahl unterschiedlicher Werte:  12
# Spaltenname:  LOR_ab_2021
# Anzahl unterschiedlicher Werte:  982
# Spaltenname:  UJAHR
# Anzahl unterschiedlicher Werte:  4
# Spaltenname:  UMONAT
# Anzahl unterschiedlicher Werte:  12
# Spaltenname:  USTUNDE
# Anzahl unterschiedlicher Werte:  24
# Spaltenname:  UWOCHENTAG
# Anzahl unterschiedlicher Werte:  7
# Spaltenname:  UKATEGORIE
# Anzahl unterschiedlicher Werte:  3
# Spaltenname:  UART
# Anzahl unterschiedlicher Werte:  10
# Spaltenname:  UTYP1
# Anzahl unterschiedlicher Werte:  7
# Spaltenname:  ULICHTVERH
# Anzahl unterschiedlicher Werte:  3
# Spaltenname:  IstRad
# Anzahl unterschiedlicher Werte:  2
# Spaltenname:  IstPKW
# Anzahl unterschiedlicher Werte:  2
# Spaltenname:  IstFuss
# Anzahl unterschiedlicher Werte:  2
# Spaltenname:  IstKrad
# Anzahl unterschiedlicher Werte:  2
# Spaltenname:  IstGkfz
# Anzahl unterschiedlicher Werte:  2
# ...
