# %%
import pandas as pd
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import KFold, cross_val_score
from sklearn.ensemble import RandomForestClassifier

df = pd.read_csv('../data/GeneralDatensatz18-21ohneGeo-mitLockdown_mitCorona.csv', sep=';')

X=df[['UMONAT','USTUNDE','UWOCHENTAG','UART','USTRZUSTAND','BEZ','UTYP1','ULICHTVERH','IstRad','IstPKW','IstFuss','IstKrad','IstGkfz','IstSonstige', 'LOCKDOWN', 'COVID']]

#für tödliche und schwere vs. leichte Unfälle
y = df['UKATEGORIE'].isin([1, 2]).astype(int)
# -> 1 ist schwer oder tödlich, 0 ist leicht

# KFold-Konfiguration
kf = KFold(n_splits=5, shuffle=True, random_state=42)

import matplotlib.pyplot as plt

# Leere Listen für F1-Scores
f1_scores_log_reg = []
f1_scores_rf = []

weights = range(0, 50)

for i in weights:
    # Logistische Regression
    log_reg = LogisticRegression(max_iter=1000, class_weight={0:1, 1: i})

    # F1-Score berechnen und speichern
    f1_reg = cross_val_score(log_reg, X, y, cv=kf, scoring='f1')
    print(f"Weight: {i} F1 Score Logistische Regression (k-fold): { f1_reg.mean()}")
    
    f1_scores_log_reg.append(f1_reg.mean())
    

    # Random Forest
    rf_clas = RandomForestClassifier(n_estimators=100, max_depth=5,random_state=42, class_weight={0:1, 1: i})

    # F1-Score berechnen und speichern
    f1_rf = cross_val_score(rf_clas, X, y, cv=kf, scoring='f1')
    print(f"Weight: {i} F1 Score Random Forest (k-fold): { f1_rf.mean()}")

    f1_scores_rf.append(f1_rf.mean())
    
# F1-Scores plotten
plt.figure(figsize=(10, 6))
plt.plot(weights, f1_scores_log_reg, marker='o', label='Logistic Regression')
plt.plot(weights, f1_scores_rf, marker='o', label='Random Forest')
plt.title('F1-Scores für verschiedene Gewichte')
plt.xlabel('Gewicht')
plt.ylabel('F1-Score')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Weight: 0 F1 Score Logistische Regression (k-fold): 0.0
# Weight: 0 F1 Score Random Forest (k-fold): 0.0
# Weight: 1 F1 Score Logistische Regression (k-fold): 0.0036244874675836827
# Weight: 1 F1 Score Random Forest (k-fold): 0.0
# Weight: 2 F1 Score Logistische Regression (k-fold): 0.07587824208890953
# Weight: 2 F1 Score Random Forest (k-fold): 0.042024596958424545
# Weight: 3 F1 Score Logistische Regression (k-fold): 0.2279615799899124
# Weight: 3 F1 Score Random Forest (k-fold): 0.243403941853889
# Weight: 4 F1 Score Logistische Regression (k-fold): 0.3077580529113283
# Weight: 4 F1 Score Random Forest (k-fold): 0.3252594693183533
# Weight: 5 F1 Score Logistische Regression (k-fold): 0.320948105016457
# Weight: 5 F1 Score Random Forest (k-fold): 0.3381518040603802
# Weight: 6 F1 Score Logistische Regression (k-fold): 0.31806317191504124
# Weight: 6 F1 Score Random Forest (k-fold): 0.3397771571363707
# Weight: 7 F1 Score Logistische Regression (k-fold): 0.3110290209673415
# Weight: 7 F1 Score Random Forest (k-fold): 0.31779084075825065
# Weight: 8 F1 Score Logistische Regression (k-fold): 0.2979895291492284
# Weight: 8 F1 Score Random Forest (k-fold): 0.30228567650744564
# Weight: 9 F1 Score Logistische Regression (k-fold): 0.2891047932350222
# Weight: 9 F1 Score Random Forest (k-fold): 0.2921151780688746
# Weight: 10 F1 Score Logistische Regression (k-fold): 0.28208486662817156
# Weight: 10 F1 Score Random Forest (k-fold): 0.28231354382565516
# Weight: 11 F1 Score Logistische Regression (k-fold): 0.27810819015107346
# Weight: 11 F1 Score Random Forest (k-fold): 0.27250573084133783
# Weight: 12 F1 Score Logistische Regression (k-fold): 0.273176761370142
# Weight: 12 F1 Score Random Forest (k-fold): 0.2683768267728568
# Weight: 13 F1 Score Logistische Regression (k-fold): 0.26938888299649993
# Weight: 13 F1 Score Random Forest (k-fold): 0.2666629731159434
# Weight: 14 F1 Score Logistische Regression (k-fold): 0.2679485106776871
# Weight: 14 F1 Score Random Forest (k-fold): 0.26650076510709847
# Weight: 15 F1 Score Logistische Regression (k-fold): 0.2670946872757188
# Weight: 15 F1 Score Random Forest (k-fold): 0.26650076510709847
# Weight: 16 F1 Score Logistische Regression (k-fold): 0.2666930095025715
# Weight: 16 F1 Score Random Forest (k-fold): 0.26650076510709847
# Weight: 17 F1 Score Logistische Regression (k-fold): 0.2664087733303698
# Weight: 17 F1 Score Random Forest (k-fold): 0.26650076510709847
# Weight: 18 F1 Score Logistische Regression (k-fold): 0.2664639013909666
# Weight: 18 F1 Score Random Forest (k-fold): 0.26650076510709847
# Weight: 19 F1 Score Logistische Regression (k-fold): 0.2664893220706192
# Weight: 19 F1 Score Random Forest (k-fold): 0.26650076510709847
# Weight: 20 F1 Score Logistische Regression (k-fold): 0.26647554534768225
# Weight: 20 F1 Score Random Forest (k-fold): 0.26650076510709847
# Weight: 21 F1 Score Logistische Regression (k-fold): 0.26650076510709847
# Weight: 21 F1 Score Random Forest (k-fold): 0.26650076510709847
# Weight: 22 F1 Score Logistische Regression (k-fold): 0.26650076510709847
# Weight: 22 F1 Score Random Forest (k-fold): 0.26650076510709847
# Weight: 23 F1 Score Logistische Regression (k-fold): 0.26650076510709847
# Weight: 23 F1 Score Random Forest (k-fold): 0.26650076510709847
# Weight: 24 F1 Score Logistische Regression (k-fold): 0.26650076510709847
# Weight: 24 F1 Score Random Forest (k-fold): 0.26650076510709847
# Weight: 25 F1 Score Logistische Regression (k-fold): 0.26650076510709847
# Weight: 25 F1 Score Random Forest (k-fold): 0.26650076510709847
# Weight: 26 F1 Score Logistische Regression (k-fold): 0.26650076510709847
# Weight: 26 F1 Score Random Forest (k-fold): 0.26650076510709847
# Weight: 27 F1 Score Logistische Regression (k-fold): 0.26650076510709847
# Weight: 27 F1 Score Random Forest (k-fold): 0.26650076510709847
# Weight: 28 F1 Score Logistische Regression (k-fold): 0.26650076510709847
# Weight: 28 F1 Score Random Forest (k-fold): 0.26650076510709847
# Weight: 29 F1 Score Logistische Regression (k-fold): 0.26650076510709847
# Weight: 29 F1 Score Random Forest (k-fold): 0.26650076510709847
# Weight: 30 F1 Score Logistische Regression (k-fold): 0.26650076510709847
# Weight: 30 F1 Score Random Forest (k-fold): 0.26650076510709847
# Weight: 31 F1 Score Logistische Regression (k-fold): 0.26650076510709847
# Weight: 31 F1 Score Random Forest (k-fold): 0.26650076510709847
# Weight: 32 F1 Score Logistische Regression (k-fold): 0.26650076510709847
# Weight: 32 F1 Score Random Forest (k-fold): 0.26650076510709847
# Weight: 33 F1 Score Logistische Regression (k-fold): 0.26650076510709847
# Weight: 33 F1 Score Random Forest (k-fold): 0.26650076510709847
# Weight: 34 F1 Score Logistische Regression (k-fold): 0.26650076510709847
# Weight: 34 F1 Score Random Forest (k-fold): 0.26650076510709847
# Weight: 35 F1 Score Logistische Regression (k-fold): 0.26650076510709847
# Weight: 35 F1 Score Random Forest (k-fold): 0.26650076510709847
# Weight: 36 F1 Score Logistische Regression (k-fold): 0.26650076510709847
# Weight: 36 F1 Score Random Forest (k-fold): 0.26650076510709847
# Weight: 37 F1 Score Logistische Regression (k-fold): 0.26650076510709847
# Weight: 37 F1 Score Random Forest (k-fold): 0.26650076510709847
# Weight: 38 F1 Score Logistische Regression (k-fold): 0.26650076510709847
# Weight: 38 F1 Score Random Forest (k-fold): 0.26650076510709847
# Weight: 39 F1 Score Logistische Regression (k-fold): 0.26650076510709847
# Weight: 39 F1 Score Random Forest (k-fold): 0.26650076510709847
# Weight: 40 F1 Score Logistische Regression (k-fold): 0.26650076510709847
# Weight: 40 F1 Score Random Forest (k-fold): 0.26650076510709847
# Weight: 41 F1 Score Logistische Regression (k-fold): 0.26650076510709847
# Weight: 41 F1 Score Random Forest (k-fold): 0.26650076510709847
# Weight: 42 F1 Score Logistische Regression (k-fold): 0.26650076510709847
# Weight: 42 F1 Score Random Forest (k-fold): 0.26650076510709847
# Weight: 43 F1 Score Logistische Regression (k-fold): 0.26650076510709847
# Weight: 43 F1 Score Random Forest (k-fold): 0.26650076510709847
# Weight: 44 F1 Score Logistische Regression (k-fold): 0.26650076510709847
# Weight: 44 F1 Score Random Forest (k-fold): 0.26650076510709847
# Weight: 45 F1 Score Logistische Regression (k-fold): 0.26650076510709847
# Weight: 45 F1 Score Random Forest (k-fold): 0.26650076510709847
# Weight: 46 F1 Score Logistische Regression (k-fold): 0.26650076510709847
# Weight: 46 F1 Score Random Forest (k-fold): 0.26650076510709847
# Weight: 47 F1 Score Logistische Regression (k-fold): 0.26650076510709847
# Weight: 47 F1 Score Random Forest (k-fold): 0.26650076510709847
# Weight: 48 F1 Score Logistische Regression (k-fold): 0.26650076510709847
# Weight: 48 F1 Score Random Forest (k-fold): 0.26650076510709847
# Weight: 49 F1 Score Logistische Regression (k-fold): 0.26650076510709847
# Weight: 49 F1 Score Random Forest (k-fold): 0.26650076510709847
