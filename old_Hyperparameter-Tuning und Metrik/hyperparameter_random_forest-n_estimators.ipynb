# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import KFold, cross_val_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import make_scorer, fbeta_score


df = pd.read_csv('GeneralDatensatz18-21ohneGeo-mitLockdown_mitCorona.csv', sep=';')

X=df[['UMONAT','USTUNDE','UWOCHENTAG','UART','USTRZUSTAND','BEZ','UTYP1','ULICHTVERH','IstRad','IstPKW','IstFuss','IstKrad','IstGkfz','IstSonstige', 'LOCKDOWN', 'COVID']]
#für tödliche Unfälle

# KFold-Konfiguration
kf = KFold(n_splits=5, shuffle=True, random_state=42)

#für tödliche und schwere vs. leichte Unfälle  -> 1 ist schwer oder tödlich, 0 ist leicht
y = df['UKATEGORIE'].isin([1, 2]).astype(int)

# %%
# erstmal alle Parameter einzeln mit class weight 9 und fbeta mit beta = 2
beta = 2
fbeta_scorer= make_scorer(fbeta_score, beta=beta)
class_weight_optimiert = {0:1, 1: 9}


max_index = 0
max_score = 0
number_trees = []
results = []



for i in range (1, 1000, 5):
    rf_clas = RandomForestClassifier(n_estimators=i, max_depth = 5, random_state=42, class_weight=class_weight_optimiert)
    result_fbeta = cross_val_score(rf_clas, X, y, cv=kf, scoring=fbeta_scorer)
    if result_fbeta.mean() > max_score: 
        max_index = i
        max_score = result_fbeta.mean()
        print(f"bester score bei: {i} bäumen")
    number_trees.append(i)
    results.append(result_fbeta.mean())
    print(f"Fbeta-score mit {i} bäumen:", result_fbeta.mean())
# Out:
# bester score bei: 1 bäumen
# Fbeta-score mit 1 bäumen: 0.47409964847302727
# bester score bei: 6 bäumen
# Fbeta-score mit 6 bäumen: 0.49204124665313004
# bester score bei: 11 bäumen
# Fbeta-score mit 11 bäumen: 0.49468051515160694
# bester score bei: 16 bäumen
# Fbeta-score mit 16 bäumen: 0.4968604767464025
# bester score bei: 21 bäumen
# Fbeta-score mit 21 bäumen: 0.49709491009181334
# Fbeta-score mit 26 bäumen: 0.495437509604303
# Fbeta-score mit 31 bäumen: 0.49559677414926717
# Fbeta-score mit 36 bäumen: 0.4962733521647036
# Fbeta-score mit 41 bäumen: 0.4968037831080423
# Fbeta-score mit 46 bäumen: 0.496996799022593
# bester score bei: 51 bäumen
# Fbeta-score mit 51 bäumen: 0.49718645076649004
# bester score bei: 56 bäumen
# Fbeta-score mit 56 bäumen: 0.49733753700543504
# Fbeta-score mit 61 bäumen: 0.4973169508422025
# bester score bei: 66 bäumen
# Fbeta-score mit 66 bäumen: 0.49742900199880713
# Fbeta-score mit 71 bäumen: 0.4969009177885174
# Fbeta-score mit 76 bäumen: 0.49729032256353084
# Fbeta-score mit 81 bäumen: 0.49705385413567643
# Fbeta-score mit 86 bäumen: 0.49700758658125405
# Fbeta-score mit 91 bäumen: 0.4971448528465884
# Fbeta-score mit 96 bäumen: 0.4971624765453546
# Fbeta-score mit 101 bäumen: 0.49708006518951714
# Fbeta-score mit 106 bäumen: 0.49704650325803124
# Fbeta-score mit 111 bäumen: 0.49726861321927524
# bester score bei: 116 bäumen
# Fbeta-score mit 116 bäumen: 0.4976128814165362
# bester score bei: 121 bäumen
# Fbeta-score mit 121 bäumen: 0.49769589304565914
# Fbeta-score mit 126 bäumen: 0.4976204059223065
# bester score bei: 131 bäumen
# Fbeta-score mit 131 bäumen: 0.49779727892680004
# bester score bei: 136 bäumen
# Fbeta-score mit 136 bäumen: 0.4978401394892016
# bester score bei: 141 bäumen
# Fbeta-score mit 141 bäumen: 0.49825448542165046
# Fbeta-score mit 146 bäumen: 0.49806279421103633
# Fbeta-score mit 151 bäumen: 0.4981270135881909
# Fbeta-score mit 156 bäumen: 0.49803795968030296
# Fbeta-score mit 161 bäumen: 0.49783578829721753
# Fbeta-score mit 166 bäumen: 0.4979767291840287
# Fbeta-score mit 171 bäumen: 0.4979007084015456
# Fbeta-score mit 176 bäumen: 0.4982360345464388
# Fbeta-score mit 181 bäumen: 0.49821596614075253
# Fbeta-score mit 186 bäumen: 0.4981183303481192
# Fbeta-score mit 191 bäumen: 0.49767290126122665
# Fbeta-score mit 196 bäumen: 0.497931194620734
# Fbeta-score mit 201 bäumen: 0.49815667480233355
# bester score bei: 206 bäumen
# Fbeta-score mit 206 bäumen: 0.4985119798920345
# Fbeta-score mit 211 bäumen: 0.4981186650972866
# Fbeta-score mit 216 bäumen: 0.49816489294600064
# Fbeta-score mit 221 bäumen: 0.4978401373843602
# Fbeta-score mit 226 bäumen: 0.4979423961398842
# Fbeta-score mit 231 bäumen: 0.4980746502918424
# Fbeta-score mit 236 bäumen: 0.49796400035051513
# Fbeta-score mit 241 bäumen: 0.4977894729049922
# Fbeta-score mit 246 bäumen: 0.4978309288092042
# Fbeta-score mit 251 bäumen: 0.49795913976938355
# Fbeta-score mit 256 bäumen: 0.49786800522648467
# Fbeta-score mit 261 bäumen: 0.4978818474196601
# Fbeta-score mit 266 bäumen: 0.49789036702607914
# Fbeta-score mit 271 bäumen: 0.49831390809432274
# Fbeta-score mit 276 bäumen: 0.49812590174599813
# Fbeta-score mit 281 bäumen: 0.4982015746500128
# Fbeta-score mit 286 bäumen: 0.4983084915396305
# bester score bei: 291 bäumen
# Fbeta-score mit 291 bäumen: 0.4985921182871351
# Fbeta-score mit 296 bäumen: 0.49855390779246556
# Fbeta-score mit 301 bäumen: 0.49850091593571655
# Fbeta-score mit 306 bäumen: 0.4985070252929071
# bester score bei: 311 bäumen
# Fbeta-score mit 311 bäumen: 0.49864675848950357
# Fbeta-score mit 316 bäumen: 0.4984557387621549
# Fbeta-score mit 321 bäumen: 0.49844211589569926
# Fbeta-score mit 326 bäumen: 0.4984353784166965
# Fbeta-score mit 331 bäumen: 0.49800979294801284
# Fbeta-score mit 336 bäumen: 0.4980469322596545
# Fbeta-score mit 341 bäumen: 0.49813122381580593
# Fbeta-score mit 346 bäumen: 0.49808305545809306
# Fbeta-score mit 351 bäumen: 0.4980753845232059
# Fbeta-score mit 356 bäumen: 0.4982994181693627
# Fbeta-score mit 361 bäumen: 0.4985128543712931
# Fbeta-score mit 366 bäumen: 0.49843742328636476
# Fbeta-score mit 371 bäumen: 0.49848592504798966
# Fbeta-score mit 376 bäumen: 0.49834811724043826
# Fbeta-score mit 381 bäumen: 0.4983288001511075
# Fbeta-score mit 386 bäumen: 0.4983343161033941
# Fbeta-score mit 391 bäumen: 0.4985617732207059
# Fbeta-score mit 396 bäumen: 0.49824232537344415
# Fbeta-score mit 401 bäumen: 0.49827786787475115
# Fbeta-score mit 406 bäumen: 0.49828475887469337
# Fbeta-score mit 411 bäumen: 0.4982447275490373
# Fbeta-score mit 416 bäumen: 0.49835420854430196
# Fbeta-score mit 421 bäumen: 0.49834541455955117
# Fbeta-score mit 426 bäumen: 0.49826538230526884
# Fbeta-score mit 431 bäumen: 0.4982374095104106
# Fbeta-score mit 436 bäumen: 0.4977797358173318
# Fbeta-score mit 441 bäumen: 0.4980667895040461
# Fbeta-score mit 446 bäumen: 0.49809432192681574
# Fbeta-score mit 451 bäumen: 0.4978394962104236
# Fbeta-score mit 456 bäumen: 0.4977978116910265
# Fbeta-score mit 461 bäumen: 0.497802989145214
# Fbeta-score mit 466 bäumen: 0.49776099643321264
# Fbeta-score mit 471 bäumen: 0.49783724059419754
# Fbeta-score mit 476 bäumen: 0.4976573005681309
# Fbeta-score mit 481 bäumen: 0.49757576498446776
# Fbeta-score mit 486 bäumen: 0.497572710145497
# Fbeta-score mit 491 bäumen: 0.49753012197892826
# Fbeta-score mit 496 bäumen: 0.4976073924099942
# Fbeta-score mit 501 bäumen: 0.4976701303269716
# Fbeta-score mit 506 bäumen: 0.49755922149413107
# Fbeta-score mit 511 bäumen: 0.4975240519950376
# Fbeta-score mit 516 bäumen: 0.4974958047716604
# Fbeta-score mit 521 bäumen: 0.49761318450180847
# Fbeta-score mit 526 bäumen: 0.4978004305110634
# Fbeta-score mit 531 bäumen: 0.497798176003618
# Fbeta-score mit 536 bäumen: 0.4978053463301956
# Fbeta-score mit 541 bäumen: 0.4977012130299843
# Fbeta-score mit 546 bäumen: 0.49768765622190553
# Fbeta-score mit 551 bäumen: 0.49771501462868517
# Fbeta-score mit 556 bäumen: 0.4979084682476748
# Fbeta-score mit 561 bäumen: 0.4978113664357888
# Fbeta-score mit 566 bäumen: 0.4978390301735236
# Fbeta-score mit 571 bäumen: 0.49776331267029594
# Fbeta-score mit 576 bäumen: 0.4977978176042779
# Fbeta-score mit 581 bäumen: 0.497790588078565
# Fbeta-score mit 586 bäumen: 0.497860229360463
# Fbeta-score mit 591 bäumen: 0.497901174154849
# Fbeta-score mit 596 bäumen: 0.49794942664616526
# Fbeta-score mit 601 bäumen: 0.4979287902270989
# Fbeta-score mit 606 bäumen: 0.4979494043516531
# Fbeta-score mit 611 bäumen: 0.4979287129448591
# Fbeta-score mit 616 bäumen: 0.49795626299680007
# Fbeta-score mit 621 bäumen: 0.49793556233846265
# Fbeta-score mit 626 bäumen: 0.4978870099715177
# Fbeta-score mit 631 bäumen: 0.4978457388067013
# Fbeta-score mit 636 bäumen: 0.4978869199577087
# Fbeta-score mit 641 bäumen: 0.497907496581802
# Fbeta-score mit 646 bäumen: 0.4979906556836059
# Fbeta-score mit 651 bäumen: 0.4979975296337358
# Fbeta-score mit 656 bäumen: 0.49794803058767007
# Fbeta-score mit 661 bäumen: 0.4980182886036486
# Fbeta-score mit 666 bäumen: 0.4980459219958592
# Fbeta-score mit 671 bäumen: 0.49800459203977454
# Fbeta-score mit 676 bäumen: 0.498058916423972
# Fbeta-score mit 681 bäumen: 0.49797603975870297
# Fbeta-score mit 686 bäumen: 0.49800366188608314
# Fbeta-score mit 691 bäumen: 0.49798277896019566
# Fbeta-score mit 696 bäumen: 0.49799659212938446
# Fbeta-score mit 701 bäumen: 0.4979413864317511
# Fbeta-score mit 706 bäumen: 0.4978859440941973
# Fbeta-score mit 711 bäumen: 0.4979344865470243
# Fbeta-score mit 716 bäumen: 0.4978372930385187
# Fbeta-score mit 721 bäumen: 0.49793296723381636
# Fbeta-score mit 726 bäumen: 0.49780152878146183
# Fbeta-score mit 731 bäumen: 0.49780871974259105
# Fbeta-score mit 736 bäumen: 0.4978917982033876
# Fbeta-score mit 741 bäumen: 0.49792082269130367
# Fbeta-score mit 746 bäumen: 0.49780198653664465
# Fbeta-score mit 751 bäumen: 0.4978645126635837
# Fbeta-score mit 756 bäumen: 0.49786447008666357
# Fbeta-score mit 761 bäumen: 0.49791309609380807
# Fbeta-score mit 766 bäumen: 0.49782305852096387
# Fbeta-score mit 771 bäumen: 0.49775364480995243
# Fbeta-score mit 776 bäumen: 0.4977815988744282
# Fbeta-score mit 781 bäumen: 0.4977055816997805
# Fbeta-score mit 786 bäumen: 0.4976914744750981
# Fbeta-score mit 791 bäumen: 0.4978713936736897
# Fbeta-score mit 796 bäumen: 0.4979214772646469
# Fbeta-score mit 801 bäumen: 0.4977888427794307
# Fbeta-score mit 806 bäumen: 0.4978313473443542
# Fbeta-score mit 811 bäumen: 0.49783855272234623
# Fbeta-score mit 816 bäumen: 0.4978179469424731
# Fbeta-score mit 821 bäumen: 0.4978180975689897
# Fbeta-score mit 826 bäumen: 0.49780418322768244
# Fbeta-score mit 831 bäumen: 0.49773501432941974
# Fbeta-score mit 836 bäumen: 0.49778334848137984
# Fbeta-score mit 841 bäumen: 0.49769909506156607
# Fbeta-score mit 846 bäumen: 0.4976784603890395
# Fbeta-score mit 851 bäumen: 0.49759549360988214
# Fbeta-score mit 856 bäumen: 0.4977748386954338
# Fbeta-score mit 861 bäumen: 0.49766478287350013
# Fbeta-score mit 866 bäumen: 0.49763862389648067
# Fbeta-score mit 871 bäumen: 0.4976526658189302
# Fbeta-score mit 876 bäumen: 0.4975545174437851
# Fbeta-score mit 881 bäumen: 0.49755473544656265
# Fbeta-score mit 886 bäumen: 0.4975338350420266
# Fbeta-score mit 891 bäumen: 0.4976445164161742
# Fbeta-score mit 896 bäumen: 0.4976785132680477
# Fbeta-score mit 901 bäumen: 0.4976578958110916
# Fbeta-score mit 906 bäumen: 0.49767859745722526
# Fbeta-score mit 911 bäumen: 0.49766490429389165
# Fbeta-score mit 916 bäumen: 0.49774090574336183
# Fbeta-score mit 921 bäumen: 0.49785298052626004
# Fbeta-score mit 926 bäumen: 0.49775480698291064
# Fbeta-score mit 931 bäumen: 0.4977338984279263
# Fbeta-score mit 936 bäumen: 0.49783213067321536
# Fbeta-score mit 941 bäumen: 0.4978265571440036
# Fbeta-score mit 946 bäumen: 0.4977203135733112
# Fbeta-score mit 951 bäumen: 0.4977406626589603
# Fbeta-score mit 956 bäumen: 0.4976922987130889
# Fbeta-score mit 961 bäumen: 0.49775334404611826
# Fbeta-score mit 966 bäumen: 0.4976982676544067
# Fbeta-score mit 986 bäumen: 0.49787268762963466
# Fbeta-score mit 991 bäumen: 0.49798740613109765
# Fbeta-score mit 996 bäumen: 0.4978683219001301

# %%
from matplotlib import pyplot as plt

# F1-Scores plotten
plt.figure(figsize=(10, 6))
plt.plot(number_trees, results)

plt.title('Tuning Anzahl Bäume')
plt.xlabel('Anzahl Bäume')
plt.ylabel('Fbeta-Score')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
result_array= np.array(results)

# %%
max = np.argmax(result_array)

# %%
max
# Out:
# 62
