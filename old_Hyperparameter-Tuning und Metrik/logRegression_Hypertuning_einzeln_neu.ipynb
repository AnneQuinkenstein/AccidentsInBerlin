# %% [markdown]
# geändert:
# - StratifiedKFold anstelle KFold
# - tolerance ist jetzt mit drin
# - bei einzel-Tuning alle anderen werte auf default (vergleichbar mit RandomForest tuning)

# %%
import pandas as pd
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score, StratifiedKFold
from sklearn.metrics import fbeta_score, make_scorer
import matplotlib.pyplot as plt

# Laden des Datensatzes
df = pd.read_csv('GeneralDatensatz18-21ohneGeo-mitLockdown_mitCorona.csv', sep=';')

# Features und Zielvariable definieren
X = df[['UMONAT','USTUNDE','UWOCHENTAG','UART','USTRZUSTAND','BEZ','UTYP1','ULICHTVERH','IstRad','IstPKW','IstFuss','IstKrad','IstGkfz','IstSonstige', 'LOCKDOWN', 'COVID']]
y = df['UKATEGORIE'].isin([1, 2]).astype(int)  # 1 für schwere/tödliche Unfälle, 0 für leichte Unfälle

# KFold-Konfiguration
sf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# Definieren des F-beta-Scores mit beta = 2
beta = 2
fbeta_scorer = make_scorer(fbeta_score, beta=beta)

##Parameter für Hyperparametertuning
float_list_Cs = [x * 0.001 for x in range(1, 50)]

logistic__C = float_list_Cs
logistic__max_iter = list(range(100, 500, 20))
logistic__tol = [1e-4, 1e-3, 1e-2]
logistic__penalty = ['l2', 'l1', 'elasticnet']
logistic__solver = ['lbfgs', 'liblinear', 'sag', 'saga']

#logistic__C: Dieser Hyperparameter steuert die Stärke der Regularisierung. Niedrigere Werte bedeuten stärkere Regularisierung, was hilfreich sein kann, um Überanpassung zu vermeiden, besonders wenn die Daten unbalanciert sind und das Modell dazu neigt, die Mehrheitsklasse zu bevorzugen.  
#logistic__penalty: Bestimmt den Typ der Regularisierung. 'l2' ist die Standardoption, die dazu neigt, die Gewichte gleichmäßig zu verkleinern, was bei unbalancierten Daten nützlich sein kann, um die Komplexität des Modells zu kontrollieren.  
#logistic__solver: Der 'lbfgs'-Solver unterstützt die L2-Regularisierung und ist effizient für kleine Datensätze. Die Wahl des Solvers kann die Konvergenzgeschwindigkeit und die Handhabung von unbalancierten Daten beeinflussen.  
#logistic__max_iter: Die maximale Anzahl von Iterationen, die der Solver für die Konvergenz durchführt. Bei unbalancierten Daten kann es notwendig sein, diesen Wert zu erhöhen, um eine bessere Anpassung zu erzielen.  
#logistic__tol: Die Toleranz für das Stoppkriterium. Eine feinere Toleranz kann bei unbalancierten Daten helfen, indem sie sicherstellt, dass das Modell gründlich optimiert wird.

# %%
logReg_logistic__C = []

for C_value in logistic__C:
    log_reg = LogisticRegression(C=C_value, max_iter = 250, class_weight={0: 1, 1: 9})
    fbeta_reg = cross_val_score(log_reg, X, y, cv=sf, scoring=fbeta_scorer)
    print(f"C_value: {C_value} Fbeta Score Logistische Regression: {fbeta_reg.mean()}")
    logReg_logistic__C.append(fbeta_reg.mean())
    

# Fbeta-Scores plotten
plt.figure(figsize=(10, 6))
plt.plot(logistic__C, logReg_logistic__C, marker='o', label='Logistic Regression')
plt.title('Fbeta-Scores für verschiedene C-Werte der Logistischen Regression')
plt.xlabel('Stärke der Regularisierung (C)')
plt.ylabel('Fbeta-Score')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# C_value: 0.001 Fbeta Score Logistische Regression: 0.48161898970299255
# C_value: 0.002 Fbeta Score Logistische Regression: 0.4820898908688383
# C_value: 0.003 Fbeta Score Logistische Regression: 0.4826926596814878
# C_value: 0.004 Fbeta Score Logistische Regression: 0.48329272073656504
# C_value: 0.005 Fbeta Score Logistische Regression: 0.4836826161797846
# C_value: 0.006 Fbeta Score Logistische Regression: 0.4838485585075446
# C_value: 0.007 Fbeta Score Logistische Regression: 0.4841024032454301
# C_value: 0.008 Fbeta Score Logistische Regression: 0.4843390152444601
# C_value: 0.009000000000000001 Fbeta Score Logistische Regression: 0.48434352193780406
# C_value: 0.01 Fbeta Score Logistische Regression: 0.48471310229056563
# C_value: 0.011 Fbeta Score Logistische Regression: 0.4848328872452581
# C_value: 0.012 Fbeta Score Logistische Regression: 0.484913835601823
# C_value: 0.013000000000000001 Fbeta Score Logistische Regression: 0.4849163792677388
# C_value: 0.014 Fbeta Score Logistische Regression: 0.4851164320290648
# C_value: 0.015 Fbeta Score Logistische Regression: 0.4851696034959406
# C_value: 0.016 Fbeta Score Logistische Regression: 0.4852152513849076
# C_value: 0.017 Fbeta Score Logistische Regression: 0.485213571184085
# C_value: 0.018000000000000002 Fbeta Score Logistische Regression: 0.4851676972365051
# C_value: 0.019 Fbeta Score Logistische Regression: 0.4851448707766896
# C_value: 0.02 Fbeta Score Logistische Regression: 0.4850994004476251
# C_value: 0.021 Fbeta Score Logistische Regression: 0.4851892005090189
# C_value: 0.022 Fbeta Score Logistische Regression: 0.485196210999346
# C_value: 0.023 Fbeta Score Logistische Regression: 0.4851367170633951
# C_value: 0.024 Fbeta Score Logistische Regression: 0.48486991765800813
# C_value: 0.025 Fbeta Score Logistische Regression: 0.4849915935851469
# C_value: 0.026000000000000002 Fbeta Score Logistische Regression: 0.484812344784023
# C_value: 0.027 Fbeta Score Logistische Regression: 0.485003226863524
# C_value: 0.028 Fbeta Score Logistische Regression: 0.4850380361046491
# C_value: 0.029 Fbeta Score Logistische Regression: 0.484987622855418
# C_value: 0.03 Fbeta Score Logistische Regression: 0.4850795429450937
# C_value: 0.031 Fbeta Score Logistische Regression: 0.4851298558233326
# C_value: 0.032 Fbeta Score Logistische Regression: 0.4851349572139762
# C_value: 0.033 Fbeta Score Logistische Regression: 0.48507057641217355
# C_value: 0.034 Fbeta Score Logistische Regression: 0.4849714891860192
# C_value: 0.035 Fbeta Score Logistische Regression: 0.48502710484034894
# C_value: 0.036000000000000004 Fbeta Score Logistische Regression: 0.4850825600872284
# C_value: 0.037 Fbeta Score Logistische Regression: 0.48504090708505093
# C_value: 0.038 Fbeta Score Logistische Regression: 0.4849679181598761
# C_value: 0.039 Fbeta Score Logistische Regression: 0.48511716428111623
# C_value: 0.04 Fbeta Score Logistische Regression: 0.4851400863463781
# C_value: 0.041 Fbeta Score Logistische Regression: 0.48518156949056285
# C_value: 0.042 Fbeta Score Logistische Regression: 0.48505296745772386
# C_value: 0.043000000000000003 Fbeta Score Logistische Regression: 0.48515205982220183
# C_value: 0.044 Fbeta Score Logistische Regression: 0.48510811687441785
# C_value: 0.045 Fbeta Score Logistische Regression: 0.48521619310287845
# C_value: 0.046 Fbeta Score Logistische Regression: 0.4851655183350411
# C_value: 0.047 Fbeta Score Logistische Regression: 0.48506443821291023
# C_value: 0.048 Fbeta Score Logistische Regression: 0.4852004734241147
# C_value: 0.049 Fbeta Score Logistische Regression: 0.4852302950788504

# %%
logReg_max_iter = []
for max_iter_value in logistic__max_iter:
    log_reg = LogisticRegression(max_iter=max_iter_value, class_weight={0: 1, 1: 9})
    fbeta_reg = cross_val_score(log_reg, X, y, cv=sf, scoring=fbeta_scorer)
    print(f"max_iter_value: {max_iter_value} Fbeta Score Logistische Regression: {fbeta_reg.mean()}")
    logReg_max_iter.append(fbeta_reg.mean())

# Fbeta-Scores plotten
plt.figure(figsize=(10, 6))
plt.plot(logistic__max_iter, logReg_max_iter, marker='o', label='Logistic Regression')
plt.title('Fbeta-Scores für verschiedene max_iter')
plt.xlabel('max_iter')
plt.ylabel('Fbeta-Score')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# /usr/local/miniconda3/envs/py3.10-cuda12.1-tf2.16/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/miniconda3/envs/py3.10-cuda12.1-tf2.16/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/miniconda3/envs/py3.10-cuda12.1-tf2.16/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/miniconda3/envs/py3.10-cuda12.1-tf2.16/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/miniconda3/envs/py3.10-cuda12.1-tf2.16/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# max_iter_value: 50 Fbeta Score Logistische Regression: 0.48410883614503675
# /usr/local/miniconda3/envs/py3.10-cuda12.1-tf2.16/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/miniconda3/envs/py3.10-cuda12.1-tf2.16/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/miniconda3/envs/py3.10-cuda12.1-tf2.16/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/miniconda3/envs/py3.10-cuda12.1-tf2.16/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/miniconda3/envs/py3.10-cuda12.1-tf2.16/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# max_iter_value: 70 Fbeta Score Logistische Regression: 0.48462246856787494
# /usr/local/miniconda3/envs/py3.10-cuda12.1-tf2.16/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/miniconda3/envs/py3.10-cuda12.1-tf2.16/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/miniconda3/envs/py3.10-cuda12.1-tf2.16/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/miniconda3/envs/py3.10-cuda12.1-tf2.16/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/miniconda3/envs/py3.10-cuda12.1-tf2.16/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# max_iter_value: 90 Fbeta Score Logistische Regression: 0.48477463531835213
# /usr/local/miniconda3/envs/py3.10-cuda12.1-tf2.16/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/miniconda3/envs/py3.10-cuda12.1-tf2.16/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/miniconda3/envs/py3.10-cuda12.1-tf2.16/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/miniconda3/envs/py3.10-cuda12.1-tf2.16/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/miniconda3/envs/py3.10-cuda12.1-tf2.16/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# max_iter_value: 110 Fbeta Score Logistische Regression: 0.48473959813057316
# /usr/local/miniconda3/envs/py3.10-cuda12.1-tf2.16/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/miniconda3/envs/py3.10-cuda12.1-tf2.16/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/miniconda3/envs/py3.10-cuda12.1-tf2.16/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# max_iter_value: 130 Fbeta Score Logistische Regression: 0.4850051842304025
# max_iter_value: 150 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 170 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 190 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 210 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 230 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 250 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 270 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 290 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 310 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 330 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 350 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 370 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 390 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 410 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 430 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 450 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 470 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 490 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 510 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 530 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 550 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 570 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 590 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 610 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 630 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 650 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 670 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 690 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 710 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 730 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 750 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 770 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 790 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 810 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 830 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 850 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 870 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 890 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 910 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 930 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 950 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 970 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 990 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 1010 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 1030 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 1050 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 1070 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 1090 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 1110 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 1130 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 1150 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 1170 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 1190 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 1210 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 1230 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 1250 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 1270 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 1290 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 1310 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 1330 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 1350 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 1370 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 1390 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 1410 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 1430 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 1450 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 1470 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 1490 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 1510 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 1530 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 1550 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 1570 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 1590 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 1610 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 1630 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 1650 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 1670 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 1690 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 1710 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 1730 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 1750 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 1770 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 1790 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 1810 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 1830 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 1850 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 1870 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 1890 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 1910 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 1930 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 1950 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 1970 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 1990 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 2010 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 2030 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 2050 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 2070 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 2090 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 2110 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 2130 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 2150 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 2170 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 2190 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 2210 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 2230 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 2250 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 2270 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 2290 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 2310 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 2330 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 2350 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 2370 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 2390 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 2410 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 2430 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 2450 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 2470 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 2490 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 2510 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 2530 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 2550 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 2570 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 2590 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 2610 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 2630 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 2650 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 2670 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 2690 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 2710 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 2730 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 2750 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 2770 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 2790 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 2810 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 2830 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 2850 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 2870 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 2890 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 2910 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 2930 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 2950 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 2970 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 2990 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 3010 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 3030 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 3050 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 3070 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 3090 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 3110 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 3130 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 3150 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 3170 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 3190 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 3210 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 3230 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 3250 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 3270 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 3290 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 3310 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 3330 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 3350 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 3370 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 3390 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 3410 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 3430 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 3450 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 3470 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 3490 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 3510 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 3530 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 3550 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 3570 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 3590 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 3610 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 3630 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 3650 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 3670 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 3690 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 3710 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 3730 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 3750 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 3770 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 3790 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 3810 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 3830 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 3850 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 3870 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 3890 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 3910 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 3930 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 3950 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 3970 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 3990 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 4010 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 4030 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 4050 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 4070 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 4090 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 4110 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 4130 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 4150 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 4170 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 4190 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 4210 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 4230 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 4250 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 4270 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 4290 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 4310 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 4330 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 4350 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 4370 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 4390 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 4410 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 4430 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 4450 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 4470 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 4490 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 4510 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 4530 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 4550 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 4570 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 4590 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 4610 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 4630 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 4650 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 4670 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 4690 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 4710 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 4730 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 4750 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 4770 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 4790 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 4810 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 4830 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 4850 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 4870 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 4890 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 4910 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 4930 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 4950 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 4970 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 4990 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 5010 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 5030 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 5050 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 5070 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 5090 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 5110 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 5130 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 5150 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 5170 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 5190 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 5210 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 5230 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 5250 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 5270 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 5290 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 5310 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 5330 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 5350 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 5370 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 5390 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 5410 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 5430 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 5450 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 5470 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 5490 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 5510 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 5530 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 5550 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 5570 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 5590 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 5610 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 5630 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 5650 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 5670 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 5690 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 5710 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 5730 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 5750 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 5770 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 5790 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 5810 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 5830 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 5850 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 5870 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 5890 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 5910 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 5930 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 5950 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 5970 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 5990 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 6010 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 6030 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 6050 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 6070 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 6090 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 6110 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 6130 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 6150 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 6170 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 6190 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 6210 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 6230 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 6250 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 6270 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 6290 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 6310 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 6330 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 6350 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 6370 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 6390 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 6410 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 6430 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 6450 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 6470 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 6490 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 6510 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 6530 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 6550 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 6570 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 6590 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 6610 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 6630 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 6650 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 6670 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 6690 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 6710 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 6730 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 6750 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 6770 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 6790 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 6810 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 6830 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 6850 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 6870 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 6890 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 6910 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 6930 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 6950 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 6970 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 6990 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 7010 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 7030 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 7050 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 7070 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 7090 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 7110 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 7130 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 7150 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 7170 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 7190 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 7210 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 7230 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 7250 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 7270 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 7290 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 7310 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 7330 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 7350 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 7370 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 7390 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 7410 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 7430 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 7450 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 7470 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 7490 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 7510 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 7530 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 7550 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 7570 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 7590 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 7610 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 7630 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 7650 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 7670 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 7690 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 7710 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 7730 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 7750 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 7770 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 7790 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 7810 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 7830 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 7850 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 7870 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 7890 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 7910 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 7930 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 7950 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 7970 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 7990 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 8010 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 8030 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 8050 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 8070 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 8090 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 8110 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 8130 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 8150 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 8170 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 8190 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 8210 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 8230 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 8250 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 8270 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 8290 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 8310 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 8330 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 8350 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 8370 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 8390 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 8410 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 8430 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 8450 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 8470 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 8490 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 8510 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 8530 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 8550 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 8570 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 8590 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 8610 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 8630 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 8650 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 8670 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 8690 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 8710 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 8730 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 8750 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 8770 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 8790 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 8810 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 8830 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 8850 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 8870 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 8890 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 8910 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 8930 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 8950 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 8970 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 8990 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 9010 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 9030 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 9050 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 9070 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 9090 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 9110 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 9130 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 9150 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 9170 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 9190 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 9210 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 9230 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 9250 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 9270 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 9290 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 9310 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 9330 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 9350 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 9370 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 9390 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 9410 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 9430 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 9450 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 9470 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 9490 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 9510 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 9530 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 9550 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 9570 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 9590 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 9610 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 9630 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 9650 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 9670 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 9690 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 9710 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 9730 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 9750 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 9770 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 9790 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 9810 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 9830 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 9850 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 9870 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 9890 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 9910 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 9930 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 9950 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 9970 Fbeta Score Logistische Regression: 0.48497041698421367
# max_iter_value: 9990 Fbeta Score Logistische Regression: 0.48497041698421367

# %%
logReg_tol = []
for tol_value in logistic__tol:
    log_reg = LogisticRegression(tol=tol_value, max_iter = 150, class_weight={0: 1, 1: 9})
    fbeta_reg = cross_val_score(log_reg, X, y, cv=sf, scoring=fbeta_scorer)
    print(f"tol_value: {tol_value} Fbeta Score Logistische Regression: {fbeta_reg.mean()}")
    logReg_tol.append(fbeta_reg.mean())

# Fbeta-Scores plotten
plt.figure(figsize=(10, 6))
plt.plot(logistic__tol, logReg_tol, marker='o', label='Logistic Regression')
plt.title('Fbeta-Scores für verschiedene tolerances')
plt.xlabel('tol')
plt.ylabel('Fbeta-Score')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# tol_value: 0.0001 Fbeta Score Logistische Regression: 0.48497041698421367
# tol_value: 0.001 Fbeta Score Logistische Regression: 0.48497041698421367
# tol_value: 0.01 Fbeta Score Logistische Regression: 0.48497041698421367

# %%
logReg_penalty = []
for penalty_value in logistic__penalty:
    log_reg = LogisticRegression(penalty=penalty_value, max_iter = 150, class_weight={0: 1, 1: 9})
    fbeta_reg = cross_val_score(log_reg, X, y, cv=sf, scoring=fbeta_scorer)
    print(f"penalty_value: {penalty_value} Fbeta Score Logistische Regression: {fbeta_reg.mean()}")
    logReg_penalty.append(fbeta_reg.mean())
    
# Fbeta-Scores plotten
plt.figure(figsize=(10, 6))
plt.plot(logistic__penalty, logReg_penalty, marker='o', label='Logistic Regression')
plt.title('Fbeta-Scores für verschiedene penalty')
plt.xlabel('penalty')
plt.ylabel('Fbeta-Score')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# penalty_value: l2 Fbeta Score Logistische Regression: 0.48497041698421367
# penalty_value: l1 Fbeta Score Logistische Regression: nan
# penalty_value: elasticnet Fbeta Score Logistische Regression: nan
# /usr/local/miniconda3/envs/py3.10-cuda12.1-tf2.16/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/miniconda3/envs/py3.10-cuda12.1-tf2.16/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/miniconda3/envs/py3.10-cuda12.1-tf2.16/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py", line 1461, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "/usr/local/miniconda3/envs/py3.10-cuda12.1-tf2.16/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py", line 447, in _check_solver
#     raise ValueError(
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got l1 penalty.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /usr/local/miniconda3/envs/py3.10-cuda12.1-tf2.16/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:372: FitFailedWarning:
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/miniconda3/envs/py3.10-cuda12.1-tf2.16/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/miniconda3/envs/py3.10-cuda12.1-tf2.16/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py", line 1461, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "/usr/local/miniconda3/envs/py3.10-cuda12.1-tf2.16/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py", line 447, in _check_solver
#     raise ValueError(
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got elasticnet penalty.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)

# %%
logReg_solver = []
for solver_value in logistic__solver:
    log_reg = LogisticRegression(solver=solver_value, max_iter = 150, class_weight={0: 1, 1: 9})
    fbeta_reg = cross_val_score(log_reg, X, y, cv=sf, scoring=fbeta_scorer)
    print(f"solver_value: {solver_value} Fbeta Score Logistische Regression (k-fold): {fbeta_reg.mean()}")
    logReg_solver.append(fbeta_reg.mean())
    
# Fbeta-Scores plotten
plt.figure(figsize=(10, 6))
plt.plot(logistic__solver, logReg_solver, marker='o', label='Logistic Regression')
plt.title('Fbeta-Scores für verschiedene solver')
plt.xlabel('solver')
plt.ylabel('Fbeta-Score')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# solver_value: lbfgs Fbeta Score Logistische Regression (k-fold): 0.48497041698421367
# solver_value: liblinear Fbeta Score Logistische Regression (k-fold): 0.48483396156063713
# /usr/local/miniconda3/envs/py3.10-cuda12.1-tf2.16/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/miniconda3/envs/py3.10-cuda12.1-tf2.16/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/miniconda3/envs/py3.10-cuda12.1-tf2.16/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/miniconda3/envs/py3.10-cuda12.1-tf2.16/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/miniconda3/envs/py3.10-cuda12.1-tf2.16/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# solver_value: sag Fbeta Score Logistische Regression (k-fold): 0.3893532572623938
# /usr/local/miniconda3/envs/py3.10-cuda12.1-tf2.16/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/miniconda3/envs/py3.10-cuda12.1-tf2.16/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/miniconda3/envs/py3.10-cuda12.1-tf2.16/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/miniconda3/envs/py3.10-cuda12.1-tf2.16/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# solver_value: saga Fbeta Score Logistische Regression (k-fold): 0.45166941192469406
# /usr/local/miniconda3/envs/py3.10-cuda12.1-tf2.16/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
